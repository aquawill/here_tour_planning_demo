# %%
# getting OAuth access token
# acquire credential from https://platform.here.com/admin/apps/

import binascii  # To convert data into ASCII
import hashlib  # To generate SHA256 digest
import hmac  # To implement HMAC algorithm
import json
import time  # To generate the OAuth timestamp
import urllib.parse  # To URLencode the parameter string
from base64 import b64encode  # To encode binary data into Base64

import requests  # To make HTTP requests


def create_parameter_string(grant_type, oauth_consumer_key, oauth_nonce, oauth_signature_method, oauth_timestamp,
                            oauth_version):
    parameter_string = ''
    parameter_string = parameter_string + 'grant_type=' + grant_type
    parameter_string = parameter_string + '&oauth_consumer_key=' + oauth_consumer_key
    parameter_string = parameter_string + '&oauth_nonce=' + oauth_nonce
    parameter_string = parameter_string + '&oauth_signature_method=' + oauth_signature_method
    parameter_string = parameter_string + '&oauth_timestamp=' + oauth_timestamp
    parameter_string = parameter_string + '&oauth_version=' + oauth_version
    return parameter_string


def create_signature(secret_key, signature_base_string):
    encoded_string = signature_base_string.encode()
    encoded_key = secret_key.encode()
    temp = hmac.new(encoded_key, encoded_string, hashlib.sha256).hexdigest()
    byte_array = b64encode(binascii.unhexlify(temp))
    return byte_array.decode()


with open('credentials.properties', mode='r') as credential_properties:  # From credentials.properties file
    lines = credential_properties.readlines()
    here_user_id = lines[0].split(' = ')[1][:-1]
    here_client_id = lines[1].split(' = ')[1][:-1]
    here_access_key_id = lines[2].split(' = ')[1][:-1]
    here_access_key_secret = lines[3].split(' = ')[1][:-1]
    here_token_endpoint_url = lines[4].split(' = ')[1][:-1]

    grant_type = 'client_credentials'

    oauth_nonce = str(int(time.time() * 1000))
    oauth_signature_method = 'HMAC-SHA256'
    oauth_timestamp = str(int(time.time()))
    oauth_version = '1.0'

    parameter_string = create_parameter_string(grant_type, here_access_key_id, oauth_nonce, oauth_signature_method,
                                               oauth_timestamp, oauth_version)
    encoded_parameter_string = urllib.parse.quote(parameter_string, safe='')

    encoded_base_string = 'POST' + '&' + urllib.parse.quote(here_token_endpoint_url, safe='')
    encoded_base_string = encoded_base_string + '&' + encoded_parameter_string

    signing_key = here_access_key_secret + '&'

    oauth_signature = create_signature(signing_key, encoded_base_string)
    encoded_oauth_signature = urllib.parse.quote(oauth_signature, safe='')

    body = {'grant_type': '{}'.format(grant_type)}

    headers = {
        'Content-Type': 'application/x-www-form-urlencoded',
        'Authorization': 'OAuth oauth_consumer_key="{0}",oauth_nonce="{1}",oauth_signature="{2}",oauth_signature_method="HMAC-SHA256",oauth_timestamp="{3}",oauth_version="1.0"'.format(
            here_access_key_id, oauth_nonce, encoded_oauth_signature, oauth_timestamp)
    }

    response = requests.post(here_token_endpoint_url, data=body, headers=headers)
    print(response.text)

    oauth_result = json.loads(response.text)
# Out:
# {"access_token":"eyJhbGciOiJSUzUxMiIsImN0eSI6IkpXVCIsImlzcyI6IkhFUkUiLCJhaWQiOiJLdjBGN2l5NzNjZnoxOHRQdXYxOCIsImlhdCI6MTcxMDczMDg5NiwiZXhwIjoxNzEwODE3Mjk2LCJraWQiOiJqMSJ9..ooMq89l18hD04wWEAUL2Pq9wnlw9AFrviJpLI0vnQz88muxbcyxcRpoY_PiL-BshdkydiE6NDHJehiJD4HmW4P8EpDlKlWXafHnNnc58qI90Kh3cnJ63L9C7hbT_MG8BoThfPYNe6FysGTcw3bdNj95L_SqJybEnGEaRjbM98uSChwlTNDhRMf-uW19-8zrWJi7J6HcF7DEmT-FxjGEPvpW6mcdshbZG9jzky9f732xtCLqukAzN1TqrwrMMic2VFBWsnW4_t8naycBC8RSIMunrjP2ALeng5xV_-pUnJkpIxGXRIp4XNDufzrGX_EGWD3dXf75J_q84YewHMU8tYg","token_type":"bearer","expires_in":86399}

# %%
# delivery target listing

import csv
destinations = 'destinations_v2.csv'
destination_list = []
f = open(destinations, encoding='utf-8')
csv = csv.DictReader(f)
for row in csv:
    destination_list.append(row)
print(destination_list)
# Out:
# [{'customer_id': 'c000001', 'name': '肯德基-花蓮中正餐廳', 'latitude': '23.97929', 'longitude': '121.61043', 'job_type': 'delivery', 'duration': '600', 'mass': '100', 'size': '1', 'priority': '2', 'time_start': '2024-11-25T01:00:00Z', 'time_end': '2024-11-25T09:00:00Z', 'task_fulfiller': '', 'estimated_time_of_arrival': '', 'actual_time_of_arrival': '', 'task_status': ''}, {'customer_id': 'c000002', 'name': '肯德基-台北台大餐廳', 'latitude': '25.01707', 'longitude': '121.53325', 'job_type': 'delivery', 'duration': '300', 'mass': '50', 'size': '1', 'priority': '2', 'time_start': '2024-11-25T01:00:00Z', 'time_end': '2024-11-25T09:00:00Z', 'task_fulfiller': '', 'estimated_time_of_arrival': '', 'actual_time_of_arrival': '', 'task_status': ''}, {'customer_id': 'c000003', 'name': '肯德基-彰化員林餐廳', 'latitude': '23.95943', 'longitude': '120.57111', 'job_type': 'delivery', 'duration': '600', 'mass': '100', 'size': '1', 'priority': '2', 'time_start': '2024-11-25T01:00:00Z', 'time_end': '2024-11-25T09:00:00Z', 'task_fulfiller': '', 'estimated_time_of_arrival': '', 'actual_time_of_arrival': '', 'task_status': ''}, {'customer_id': 'c000004', 'name': '肯德基-中和興南餐廳', 'latitude': '24.98914', 'longitude': '121.50996', 'job_type': 'delivery', 'duration': '300', 'mass': '50', 'size': '1', 'priority': '2', 'time_start': '2024-11-25T01:00:00Z', 'time_end': '2024-11-25T09:00:00Z', 'task_fulfiller': '', 'estimated_time_of_arrival': '', 'actual_time_of_arrival': '', 'task_status': ''}, {'customer_id': 'c000005', 'name': '肯德基-嘉義忠孝餐廳', 'latitude': '23.49499', 'longitude': '120.45175', 'job_type': 'delivery', 'duration': '600', 'mass': '100', 'size': '1', 'priority': '2', 'time_start': '2024-11-25T01:00:00Z', 'time_end': '2024-11-25T09:00:00Z', 'task_fulfiller': '', 'estimated_time_of_arrival': '', 'actual_time_of_arrival': '', 'task_status': ''}, {'customer_id': 'c000006', 'name': '肯德基-高雄十全餐廳', 'latitude': '22.64501', 'longitude': '120.30923', 'job_type': 'delivery', 'duration': '300', 'mass': '50', 'size': '1', 'priority': '2', 'time_start': '2024-11-25T01:00:00Z', 'time_end': '2024-11-25T09:00:00Z', 'task_fulfiller': '', 'estimated_time_of_arrival': '', 'actual_time_of_arrival': '', 'task_status': ''}, {'customer_id': 'c000007', 'name': '肯德基-土城裕民餐廳', 'latitude': '24.98545', 'longitude': '121.45267', 'job_type': 'delivery', 'duration': '600', 'mass': '100', 'size': '1', 'priority': '2', 'time_start': '2024-11-25T01:00:00Z', 'time_end': '2024-11-25T09:00:00Z', 'task_fulfiller': '', 'estimated_time_of_arrival': '', 'actual_time_of_arrival': '', 'task_status': ''}, {'customer_id': 'c000008', 'name': '肯德基-台北石牌餐廳', 'latitude': '25.11494', 'longitude': '121.51556', 'job_type': 'delivery', 'duration': '300', 'mass': '50', 'size': '1', 'priority': '2', 'time_start': '2024-11-25T01:00:00Z', 'time_end': '2024-11-25T09:00:00Z', 'task_fulfiller': '', 'estimated_time_of_arrival': '', 'actual_time_of_arrival': '', 'task_status': ''}, {'customer_id': 'c000009', 'name': '肯德基-嘉義垂楊餐廳', 'latitude': '23.47376', 'longitude': '120.44832', 'job_type': 'delivery', 'duration': '600', 'mass': '100', 'size': '1', 'priority': '2', 'time_start': '2024-11-25T01:00:00Z', 'time_end': '2024-11-25T09:00:00Z', 'task_fulfiller': '', 'estimated_time_of_arrival': '', 'actual_time_of_arrival': '', 'task_status': ''}, {'customer_id': 'c000010', 'name': '肯德基-中和福祥餐廳', 'latitude': '25.00264', 'longitude': '121.49895', 'job_type': 'delivery', 'duration': '300', 'mass': '50', 'size': '1', 'priority': '2', 'time_start': '2024-11-25T01:00:00Z', 'time_end': '2024-11-25T09:00:00Z', 'task_fulfiller': '', 'estimated_time_of_arrival': '', 'actual_time_of_arrival': '', 'task_status': ''}, {'customer_id': 'c000011', 'name': '肯德基-台北中崙餐廳', 'latitude': '25.04721', 'longitude': '121.54245', 'job_type': 'delivery', 'duration': '600', 'mass': '100', 'size': '1', 'priority': '2', 'time_start': '2024-11-25T01:00:00Z', 'time_end': '2024-11-25T09:00:00Z', 'task_fulfiller': '', 'estimated_time_of_arrival': '', 'actual_time_of_arrival': '' ...

# %%
# delivery vehicle listing

import csv

destinations = 'fleet.csv'
f = open(destinations, encoding='utf-8')
csv = csv.reader(f)
for row in csv:
    print(row)
# Out:
# ['vehicle_id', 'type', 'name', 'cost_distance', 'cost_time', 'cost_fixed', 'shift_start', 'shift_end', 'start_latitude', 'start_longitude', 'end_latitude', 'end_longitude', 'break_start', 'break_end', 'break_duration', 'capacity_mass', 'capacity_size', 'max_distance', 'shift_time', 'amount']
# ['isuzu', 'truck', 'ISUZU_NLR', '0.004', '0.033', '1600', '2024-11-25T00:00:00Z', '2024-11-25T09:00:00Z', '25.0633628527129', '121.5517443657892', '24.970504', '121.2516', '2024-11-25T04:00:00Z', '2024-11-25T05:00:00Z', '3600', '3500', '40', '600000', '28800', '5']
# ['mitsubishi', 'truck', 'MITSUBISHI_CANTER', '0.005', '0.04', '2000', '2024-11-25T00:00:00Z', '2024-11-25T09:00:00Z', '22.570109085287', '120.34168946760741', '24.970504', '121.2516', '2024-11-25T04:00:00Z', '2024-11-25T05:00:00Z', '3600', '3500', '50', '600000', '28800', '5']

# %%
# composing HERE Tour Planning API request body

import csv
import json

destinations = 'destinations_v2.csv'
vehicles = 'fleet.csv'

jobs = []
types = []
profiles = []

with open(destinations, encoding='utf-8') as destinations:
    reader = csv.DictReader(destinations)
    for row in reader:
        job_type = row['job_type']
        if job_type == 'delivery':
            jobs.append({
                "id": row['customer_id'],
                "tasks": {
                "deliveries": [
                    {
                    "places": [
                        {
                        "times": [
                            [row['time_start'],
                            row['time_end']]
                        ],
                        "location": {
                            "lat": float(row['latitude']),
                            "lng": float(row['longitude'])
                        },
                        "duration": int(row['duration'])
                        }
                    ],
                    "demand": [int(row['size'])]
                    }   
                ],
                },
                "priority": int(row['priority'])
            }
        )
        


with open(vehicles, encoding='utf-8') as vehicle_list:
    reader = csv.DictReader(vehicle_list)
    for row in reader:
        types.append({
            "id": row['vehicle_id'],
            "profile": row['name'],
            "costs": {
                "fixed": float(row['cost_fixed']),
                "distance": float(row['cost_distance']),
                "time": float(row['cost_time'])
            },
            "shifts": [
                {
                    "start": {
                        "time": row['shift_start'],
                        "location": {
                            "lat": float(row['start_latitude']),
                            "lng": float(row['start_longitude'])
                        }
                    },
                    "end": {
                        "time": row['shift_end'],
                        "location": {
                            "lat": float(row['end_latitude']),
                            "lng": float(row['end_longitude'])
                        }
                    },
                    "breaks": [
                        {
                            "times": [
                                [
                                    row['break_start'],
                                    row['break_end']
                                ]
                            ],
                            "duration": int(row['break_duration']),
                        }
                    ]
                }
            ],
            "capacity": [
                int(row['capacity_mass']),
                int(row['capacity_size'])
            ],
            "skills": [
                "fridge"
            ],
            "limits": {
                "maxDistance": int(row['max_distance']),
                "shiftTime": int(row['shift_time'])
            },
            "amount": int(row['amount'])
        })
        profiles.append({
            "name": row['name'],
            "type": row['type']
        })

problem = {
    "plan": {
        "jobs": jobs,
    },
    "fleet": {
        "types": types,
        "profiles": profiles
    },
    "configuration": {
        "termination": {
            "maxTime": 240,
            "stagnationTime": 1
         }
    }
}

data = json.dumps(problem, ensure_ascii=False)

print(data)
# Out:
# {"plan": {"jobs": [{"id": "c000001", "tasks": {"deliveries": [{"places": [{"times": [["2024-11-25T01:00:00Z", "2024-11-25T09:00:00Z"]], "location": {"lat": 23.97929, "lng": 121.61043}, "duration": 600}], "demand": [1]}]}, "priority": 2}, {"id": "c000002", "tasks": {"deliveries": [{"places": [{"times": [["2024-11-25T01:00:00Z", "2024-11-25T09:00:00Z"]], "location": {"lat": 25.01707, "lng": 121.53325}, "duration": 300}], "demand": [1]}]}, "priority": 2}, {"id": "c000003", "tasks": {"deliveries": [{"places": [{"times": [["2024-11-25T01:00:00Z", "2024-11-25T09:00:00Z"]], "location": {"lat": 23.95943, "lng": 120.57111}, "duration": 600}], "demand": [1]}]}, "priority": 2}, {"id": "c000004", "tasks": {"deliveries": [{"places": [{"times": [["2024-11-25T01:00:00Z", "2024-11-25T09:00:00Z"]], "location": {"lat": 24.98914, "lng": 121.50996}, "duration": 300}], "demand": [1]}]}, "priority": 2}, {"id": "c000005", "tasks": {"deliveries": [{"places": [{"times": [["2024-11-25T01:00:00Z", "2024-11-25T09:00:00Z"]], "location": {"lat": 23.49499, "lng": 120.45175}, "duration": 600}], "demand": [1]}]}, "priority": 2}, {"id": "c000006", "tasks": {"deliveries": [{"places": [{"times": [["2024-11-25T01:00:00Z", "2024-11-25T09:00:00Z"]], "location": {"lat": 22.64501, "lng": 120.30923}, "duration": 300}], "demand": [1]}]}, "priority": 2}, {"id": "c000007", "tasks": {"deliveries": [{"places": [{"times": [["2024-11-25T01:00:00Z", "2024-11-25T09:00:00Z"]], "location": {"lat": 24.98545, "lng": 121.45267}, "duration": 600}], "demand": [1]}]}, "priority": 2}, {"id": "c000008", "tasks": {"deliveries": [{"places": [{"times": [["2024-11-25T01:00:00Z", "2024-11-25T09:00:00Z"]], "location": {"lat": 25.11494, "lng": 121.51556}, "duration": 300}], "demand": [1]}]}, "priority": 2}, {"id": "c000009", "tasks": {"deliveries": [{"places": [{"times": [["2024-11-25T01:00:00Z", "2024-11-25T09:00:00Z"]], "location": {"lat": 23.47376, "lng": 120.44832}, "duration": 600}], "demand": [1]}]}, "priority": 2}, {"id": "c000010", "tasks": {"deliveries": [{"places": [{"times": [["2024-11-25T01:00:00Z", "2024-11-25T09:00:00Z"]], "location": {"lat": 25.00264, "lng": 121.49895}, "duration": 300}], "demand": [1]}]}, "priority": 2}, {"id": "c000011", "tasks": {"deliveries": [{"places": [{"times": [["2024-11-25T01:00:00Z", "2024-11-25T09:00:00Z"]], "location": {"lat": 25.04721, "lng": 121.54245}, "duration": 600}], "demand": [1]}]}, "priority": 2}, {"id": "c000012", "tasks": {"deliveries": [{"places": [{"times": [["2024-11-25T01:00:00Z", "2024-11-25T09:00:00Z"]], "location": {"lat": 22.79388, "lng": 120.29578}, "duration": 300}], "demand": [1]}]}, "priority": 2}, {"id": "c000013", "tasks": {"deliveries": [{"places": [{"times": [["2024-11-25T01:00:00Z", "2024-11-25T09:00:00Z"]], "location": {"lat": 23.00881, "lng": 120.20743}, "duration": 600}], "demand": [1]}]}, "priority": 2}, {"id": "c000014", "tasks": {"deliveries": [{"places": [{"times": [["2024-11-25T01:00:00Z", "2024-11-25T09:00:00Z"]], "location": {"lat": 25.14038, "lng": 121.45975}, "duration": 300}], "demand": [1]}]}, "priority": 2}, {"id": "c000015", "tasks": {"deliveries": [{"places": [{"times": [["2024-11-25T01:00:00Z", "2024-11-25T09:00:00Z"]], "location": {"lat": 22.56732, "lng": 120.35157}, "duration": 600}], "demand": [1]}]}, "priority": 2}, {"id": "c000016", "tasks": {"deliveries": [{"places": [{"times": [["2024-11-25T01:00:00Z", "2024-11-25T09:00:00Z"]], "location": {"lat": 25.04663, "lng": 121.51537}, "duration": 300}], "demand": [1]}]}, "priority": 2}, {"id": "c000017", "tasks": {"deliveries": [{"places": [{"times": [["2024-11-25T01:00:00Z", "2024-11-25T09:00:00Z"]], "location": {"lat": 24.98616, "lng": 121.46479}, "duration": 600}], "demand": [1]}]}, "priority": 2}, {"id": "c000018", "tasks": {"deliveries": [{"places": [{"times": [["2024-11-25T01:00:00Z", "2024-11-25T09:00:00Z"]], "location": {"lat": 25.01751, "lng": 121.47736}, "duration": 300}], "demand": [1]}]}, "priority": 2}, {"id": "c000019", "tasks": {"deliveries ...

# %%
# request HERE Tour Planning API V3 to get planning results

import requests

tour_planning_api_url = "https://tourplanning.hereapi.com/v3/problems"

headers = {
  'Content-Type': 'application/json',
  'Authorization': '{} {}'.format(oauth_result['token_type'], oauth_result['access_token'])
}

r = requests.request('POST', tour_planning_api_url, headers=headers, data = data)
j = json.loads(r.text)

print('result:\n{}'.format(r.text))
print('response_time: {}'.format(r.elapsed.total_seconds()))
# Out:
# result:
# {"statistic":{"cost":41069.052,"distance":2725485,"duration":284221,"times":{"driving":193021,"serving":66000,"waiting":0,"stopping":0,"break":25200}},"tours":[{"vehicleId":"isuzu_5","typeId":"isuzu","stops":[{"time":{"arrival":"2024-11-25T00:00:00Z","departure":"2024-11-25T00:49:08Z"},"load":[26],"activities":[{"jobId":"departure","type":"departure","location":{"lat":25.0633628527129,"lng":121.5517443657892},"time":{"start":"2024-11-25T00:00:00Z","end":"2024-11-25T00:49:08Z"}}],"location":{"lat":25.0633628527129,"lng":121.5517443657892},"distance":0},{"time":{"arrival":"2024-11-25T01:02:32Z","departure":"2024-11-25T01:17:32Z"},"load":[24],"activities":[{"jobId":"c000118","type":"delivery","location":{"lat":25.04745,"lng":121.51614},"time":{"start":"2024-11-25T01:02:32Z","end":"2024-11-25T01:07:32Z"}},{"jobId":"c000117","type":"delivery","location":{"lat":25.04745,"lng":121.51614},"time":{"start":"2024-11-25T01:07:32Z","end":"2024-11-25T01:17:32Z"}}],"location":{"lat":25.04745,"lng":121.51614},"distance":6131},{"time":{"arrival":"2024-11-25T01:22:27Z","departure":"2024-11-25T01:27:27Z"},"load":[23],"activities":[{"jobId":"c000078","type":"delivery","location":{"lat":25.0578,"lng":121.52166},"time":{"start":"2024-11-25T01:22:27Z","end":"2024-11-25T01:27:27Z"}}],"location":{"lat":25.0578,"lng":121.52166},"distance":7610},{"time":{"arrival":"2024-11-25T01:34:01Z","departure":"2024-11-25T01:39:01Z"},"load":[22],"activities":[{"jobId":"c000082","type":"delivery","location":{"lat":25.06293,"lng":121.49969},"time":{"start":"2024-11-25T01:34:01Z","end":"2024-11-25T01:39:01Z"}}],"location":{"lat":25.06293,"lng":121.49969},"distance":10510},{"time":{"arrival":"2024-11-25T01:40:52Z","departure":"2024-11-25T01:50:52Z"},"load":[21],"activities":[{"jobId":"c000153","type":"delivery","location":{"lat":25.06667,"lng":121.4966},"time":{"start":"2024-11-25T01:40:52Z","end":"2024-11-25T01:50:52Z"}}],"location":{"lat":25.06667,"lng":121.4966},"distance":11217},{"time":{"arrival":"2024-11-25T01:56:46Z","departure":"2024-11-25T02:01:46Z"},"load":[20],"activities":[{"jobId":"c000032","type":"delivery","location":{"lat":25.07921,"lng":121.48224},"time":{"start":"2024-11-25T01:56:46Z","end":"2024-11-25T02:01:46Z"}}],"location":{"lat":25.07921,"lng":121.48224},"distance":13390},{"time":{"arrival":"2024-11-25T02:05:14Z","departure":"2024-11-25T02:15:14Z"},"load":[19],"activities":[{"jobId":"c000021","type":"delivery","location":{"lat":25.08714,"lng":121.47138},"time":{"start":"2024-11-25T02:05:14Z","end":"2024-11-25T02:15:14Z"}}],"location":{"lat":25.08714,"lng":121.47138},"distance":14878},{"time":{"arrival":"2024-11-25T02:25:41Z","departure":"2024-11-25T02:35:41Z"},"load":[18],"activities":[{"jobId":"c000137","type":"delivery","location":{"lat":25.08458,"lng":121.4385},"time":{"start":"2024-11-25T02:25:41Z","end":"2024-11-25T02:35:41Z"}}],"location":{"lat":25.08458,"lng":121.4385},"distance":20006},{"time":{"arrival":"2024-11-25T02:43:33Z","departure":"2024-11-25T02:53:33Z"},"load":[17],"activities":[{"jobId":"c000107","type":"delivery","location":{"lat":25.05904,"lng":121.43136},"time":{"start":"2024-11-25T02:43:33Z","end":"2024-11-25T02:53:33Z"}}],"location":{"lat":25.05904,"lng":121.43136},"distance":23027},{"time":{"arrival":"2024-11-25T03:10:17Z","departure":"2024-11-25T03:20:17Z"},"load":[16],"activities":[{"jobId":"c000051","type":"delivery","location":{"lat":25.06991,"lng":121.37173},"time":{"start":"2024-11-25T03:10:17Z","end":"2024-11-25T03:20:17Z"}}],"location":{"lat":25.06991,"lng":121.37173},"distance":30916},{"time":{"arrival":"2024-11-25T03:27:35Z","departure":"2024-11-25T03:32:35Z"},"load":[15],"activities":[{"jobId":"c000060","type":"delivery","location":{"lat":25.05909,"lng":121.36743},"time":{"start":"2024-11-25T03:27:35Z","end":"2024-11-25T03:32:35Z"}}],"location":{"lat":25.05909,"lng":121.36743},"distance":33037},{"time":{"arrival":"2024-11-25T03:45:37Z","departure":"2024-11-25T03:50:37Z"},"load":[14],"activities":[{"jobId":"c0000 ...
# response_time: 5.070709

# %%
import json
import random

import flexpolyline
import folium
import requests
from folium.plugins import BeautifyIcon, AntPath

import solution_v3 as solution


def get_route(ori_lat, ori_lon, dest_lat, dest_lon, route_mode, departure_time):
    route_url = 'https://router.hereapi.com/v8/routes?'
    wp0 = ('{},{}'.format(ori_lat, ori_lon))
    wp1 = ('{},{}'.format(dest_lat, dest_lon))
    route_options = '&transportMode={}&departureTime={}&return=polyline'.format(route_mode, departure_time)
    url = route_url + 'apiKey=' + apikey + '&origin=' + wp0 + '&destination=' + wp1 + route_options
    json_result = json.loads(requests.get(url).text)
    routes = json_result['routes']
    route_shape = []
    decoded_polyline = flexpolyline.decode(routes[0]['sections'][0]['polyline'])
    return decoded_polyline


with open('apikey.txt', mode='r') as apikey_txt:
    apikey = apikey_txt.read()

m = folium.Map(
    tiles='https://1.base.maps.ls.hereapi.com/maptile/2.1/maptile/newest/normal.day/{z}/{x}/{y}/256/png8?apiKey=' + apikey,
    location=[23, 121],
    max_zoom=20,
    attr='(c)2021 HERE'
)

folium.Marker([25.0633628527129, 121.5517443657892],
              icon=BeautifyIcon(icon='home', iconShape='marker', background_color='#000000', text_color='#FFFFFF'),
              popup='Home').add_to(m)
folium.Marker([22.570109085287, 120.34168946760741],
              icon=BeautifyIcon(icon='home', iconShape='marker', background_color='#000000', text_color='#FFFFFF'),
              popup='Home').add_to(m)

bounds = []

customer_dict = {}
unreachable_customer_names = []
solution = solution.solution_from_dict(j)
unassigned = solution.unassigned
unassigned_feature_group = folium.map.FeatureGroup(name='Unassigned', overlay=True, control=True, show=True)
icon_color = '#FF0000'
for destination_dict in destination_list:
    customer_dict[destination_dict['customer_id']] = destination_dict['name']
    if len(unassigned) > 0:
        for unassigned_destination in unassigned:
            job_id = unassigned_destination.job_id
            customer_name = ''
            if destination_dict['customer_id'] == job_id:
                customer_name = destination_dict['name']
                unreachable_customer_names.append(customer_name)
                folium.Marker([destination_dict['latitude'], destination_dict['longitude']],
                              icon=BeautifyIcon(icon='ban', iconShape='marker', background_color=icon_color,
                                                border_width=2), popup='{}/{}<br>{}'.format(job_id, customer_name,
                                                                                            unassigned_destination.reasons.__getitem__(
                                                                                                0).description)).add_to(
                    unassigned_feature_group)
unassigned_feature_group.add_to(m)
print("unreachable customers: ")
print(unreachable_customer_names)

tour_index = 0
tour_list = []
vehicle_list = []
while tour_index < len(solution.tours):
    icon_color = '#'
    i = 0
    while i < 6:
        icon_color += hex(random.randint(6, 16))[-1]
        i += 1
    tour = solution.tours.__getitem__(tour_index)
    vehicle_id = tour.vehicle_id
    vehicle_list.append(vehicle_id)
    statistic = tour.statistic
    print("\ncalculating routes for tour: {} / vehicle: {} / stops: {} / cost: {} / distance: {} / duration: {}".format(
        tour_index, vehicle_id, len(tour.stops), int(statistic.cost), statistic.distance, statistic.duration))
    feature_group = folium.map.FeatureGroup(name=vehicle_id, overlay=True, control=True, show=True)
    type_id = tour.type_id
    stops = tour.stops
    stop_index = 0
    stop_list = []
    trip_start_timestamp = 0
    trip_end_timestamp = 0
    movement_time = 0
    while stop_index < len(stops):
        stop = stops.__getitem__(stop_index)
        previous_stop = stops.__getitem__(stop_index - 1)
        stop_location = stop.location.to_dict()
        stop_time = stop.time
        stop_time_arrival = stop.time.arrival
        stop_time_departure = stop.time.departure
        stop_time_arrival_from_trip_start = 0
        stop_time_departure_from_trip_start = 0
        stop_activities = stop.activities

        if stop_index == 0:
            trip_start_timestamp = stop_time_departure
        else:
            stop_time_arrival_from_trip_start = stop_time_arrival - trip_start_timestamp
            stop_time_departure_from_trip_start = stop_time_departure - trip_start_timestamp
        print('\tstop_time_arrival_from_trip_start: {}'.format(stop_time_arrival_from_trip_start))
        print('\tstop_time_departure_from_trip_start: {}'.format(stop_time_departure_from_trip_start))
        if stop_index > 0:
            previous_stop = stops.__getitem__(stop_index - 1)
            movement_time = stop_time.arrival - previous_stop.time.departure
            movement_time.seconds
            print('\t~ movement time: {} ~'.format(movement_time))
        for stop_activity in stop_activities:
            job_id = stop_activity.job_id
            for destination_dict in destination_list:
                if destination_dict['customer_id'] == job_id:
                    stop_list.append({'stop_index': stop_index, 'job_id': job_id, 'destination': destination_dict})
                elif job_id == 'departure' or job_id == 'arrival' or job_id == 'break':
                    stop_list.append({'stop_index': stop_index, 'job_id': job_id,
                                      'destination': {'latitude': stop_location['lat'],
                                                      'longitude': stop_location['lng']}})
                    break
            customer_name = customer_dict.get(job_id)
            stop_load = stop.load
            if stop_index < len(stops) - 1:
                route_shape = get_route(stop_location['lat'], stop_location['lng'],
                                        stops.__getitem__(stop_index + 1).location.to_dict()['lat'],
                                        stops.__getitem__(stop_index + 1).location.to_dict()['lng'], 'truck',
                                        stop_time_departure.strftime('%Y-%m-%dT%H:%M:%SZ'))
                if stop_index > 0:
                    folium.Marker([stop_location['lat'], stop_location['lng']],
                                  icon=BeautifyIcon(icon='flag', iconShape='marker', background_color=icon_color,
                                                    border_width=2),
                                  popup='Vehicle ID: {}<br>Job ID: {}/{}<br>Arrival：{}<br>Departure：{}'.format(
                                      vehicle_id, job_id, customer_name, stop_time_arrival,
                                      stop_time_departure)).add_to(feature_group)
                shape_point_index = 0
                bounds.append([stop_location['lat'], stop_location['lng']])
                shape_point_list = []
                while shape_point_index < len(route_shape):
                    shape_point = route_shape[shape_point_index]
                    shape_point_list.append(shape_point)
                    shape_point_index += 1
                AntPath(shape_point_list, color=icon_color, weight=4, opacity=1).add_to(feature_group)
            print('{} --> {} / {} / {} / arr: {} dep: {} '.format(stop_index, job_id, customer_name,
                                                                  [stop_location['lat'], stop_location['lng']],
                                                                  stop_time.arrival, stop_time.departure))

        stop_index += 1
    statistic = tour.statistic
    tour_list.append({'vehicle_id': vehicle_id, 'stop_list': stop_list})
    feature_group.add_to(m)
    tour_index += 1
# Out:
# unreachable customers:
# ['肯德基-花蓮中正餐廳', '肯德基-宜蘭羅東餐廳', '肯德基-台東新生餐廳', '肯德基-台南中華餐廳', '肯德基-屏東逢甲餐廳', '肯德基-南投埔里餐廳', '肯德基-台南中華西餐廳', '肯德基-斗六民生餐廳', '肯德基-屏東自由餐廳', '肯德基-彰化鹿港餐廳', '肯德基-汐止中興餐廳', '肯德基-羅東興東餐廳']
#
# calculating routes for tour: 0 / vehicle: isuzu_5 / stops: 27 / cost: 2967 / distance: 106113 / duration: 28584
# 	stop_time_arrival_from_trip_start: 0
# 	stop_time_departure_from_trip_start: 0
# 0 --> departure / None / [25.0633628527129, 121.5517443657892] / arr: 2024-11-25 00:00:00+00:00 dep: 2024-11-25 00:49:08+00:00
# 	stop_time_arrival_from_trip_start: 0:13:24
# 	stop_time_departure_from_trip_start: 0:28:24
# 	~ movement time: 0:13:24 ~
# 1 --> c000118 / 肯德基-台北車站B2餐廳 / [25.04745, 121.51614] / arr: 2024-11-25 01:02:32+00:00 dep: 2024-11-25 01:17:32+00:00
# 1 --> c000117 / 肯德基-台北車站B1餐廳 / [25.04745, 121.51614] / arr: 2024-11-25 01:02:32+00:00 dep: 2024-11-25 01:17:32+00:00
# 	stop_time_arrival_from_trip_start: 0:33:19
# 	stop_time_departure_from_trip_start: 0:38:19
# 	~ movement time: 0:04:55 ~
# 2 --> c000078 / 肯德基-台北雙連餐廳 / [25.0578, 121.52166] / arr: 2024-11-25 01:22:27+00:00 dep: 2024-11-25 01:27:27+00:00
# 	stop_time_arrival_from_trip_start: 0:44:53
# 	stop_time_departure_from_trip_start: 0:49:53
# 	~ movement time: 0:06:34 ~
# 3 --> c000082 / 肯德基-三重重新二餐廳 / [25.06293, 121.49969] / arr: 2024-11-25 01:34:01+00:00 dep: 2024-11-25 01:39:01+00:00
# 	stop_time_arrival_from_trip_start: 0:51:44
# 	stop_time_departure_from_trip_start: 1:01:44
# 	~ movement time: 0:01:51 ~
# 4 --> c000153 / 肯德基-三重正義餐廳 / [25.06667, 121.4966] / arr: 2024-11-25 01:40:52+00:00 dep: 2024-11-25 01:50:52+00:00
# 	stop_time_arrival_from_trip_start: 1:07:38
# 	stop_time_departure_from_trip_start: 1:12:38
# 	~ movement time: 0:05:54 ~
# 5 --> c000032 / 肯德基-三重三和餐廳 / [25.07921, 121.48224] / arr: 2024-11-25 01:56:46+00:00 dep: 2024-11-25 02:01:46+00:00
# 	stop_time_arrival_from_trip_start: 1:16:06
# 	stop_time_departure_from_trip_start: 1:26:06
# 	~ movement time: 0:03:28 ~
# 6 --> c000021 / 肯德基-蘆洲三民餐廳 / [25.08714, 121.47138] / arr: 2024-11-25 02:05:14+00:00 dep: 2024-11-25 02:15:14+00:00
# 	stop_time_arrival_from_trip_start: 1:36:33
# 	stop_time_departure_from_trip_start: 1:46:33
# 	~ movement time: 0:10:27 ~
# 7 --> c000137 / 肯德基-五股成泰餐廳 / [25.08458, 121.4385] / arr: 2024-11-25 02:25:41+00:00 dep: 2024-11-25 02:35:41+00:00
# 	stop_time_arrival_from_trip_start: 1:54:25
# 	stop_time_departure_from_trip_start: 2:04:25
# 	~ movement time: 0:07:52 ~
# 8 --> c000107 / 肯德基-泰山明志餐廳 / [25.05904, 121.43136] / arr: 2024-11-25 02:43:33+00:00 dep: 2024-11-25 02:53:33+00:00
# 	stop_time_arrival_from_trip_start: 2:21:09
# 	stop_time_departure_from_trip_start: 2:31:09
# 	~ movement time: 0:16:44 ~
# 9 --> c000051 / 肯德基-林口文化餐廳 / [25.06991, 121.37173] / arr: 2024-11-25 03:10:17+00:00 dep: 2024-11-25 03:20:17+00:00
# 	stop_time_arrival_from_trip_start: 2:38:27
# 	stop_time_departure_from_trip_start: 2:43:27
# 	~ movement time: 0:07:18 ~
# 10 --> c000060 / 肯德基-林口復興餐廳 / [25.05909, 121.36743] / arr: 2024-11-25 03:27:35+00:00 dep: 2024-11-25 03:32:35+00:00
# 	stop_time_arrival_from_trip_start: 2:56:29
# 	stop_time_departure_from_trip_start: 3:01:29
# 	~ movement time: 0:13:02 ~
# 11 --> c000066 / 肯德基-南崁中正餐廳 / [25.04407, 121.29408] / arr: 2024-11-25 03:45:37+00:00 dep: 2024-11-25 03:50:37+00:00
# 	stop_time_arrival_from_trip_start: 3:04:25
# 	stop_time_departure_from_trip_start: 3:14:25
# 	~ movement time: 0:02:56 ~
# 12 --> c000059 / 肯德基-桃園台茂餐廳 / [25.05292, 121.28768] / arr: 2024-11-25 03:53:33+00:00 dep: 2024-11-25 04:03:33+00:00
# 	stop_time_arrival_from_trip_start: 3:34:05
# 	stop_time_departure_from_trip_start: 4:39:05
# 	~ movement time: 0:19:40 ~
# 13 --> c000106 / 肯德基-桃園中正餐廳 / [24.99061, 121.31294] / arr: 2024-11-25 04:23:13+00:00 dep: 2024-11-25 05:28:13+00:00
# 13 --> break / None / [24.99061, 121.31294] / arr: 2024-11-25 04:23:13+00:00 dep: 2024-11-25 05:28:13+00:00
# 	stop_time_arrival_from_trip_start: 4:45:20
# 	stop_time_departure_from_trip_start: 4:50:20
# 	~ movement time: 0:06:15 ~
# 14 --> c000136 / 肯德基-桃園桃鶯餐廳 / [24.98354, 121.31872] / arr: 2024-11-25 05:34:28+00:00 dep: 2024-11-25 05:39:28+00:00
# 	stop_time_arrival_from_trip_start: 4:59:24
# 	stop_time_departure_from_trip_start: 5:09:24
# 	~ movement time: 0:09:04 ~
# 15 --> c000073 / 肯德基-桃園經國餐廳 / [25.01499, 121.30609] / arr: 2024-11-25 05:48:32+00:00 dep: 2024-11-25 05:58:32+00:00
# 	stop_time_arrival_from_trip_start: 5:12:38
# 	stop_time_departure_from_trip_start: 5:17:38
# 	~ movement time: 0:03:14 ~
# 16 --> c000042 / 肯德基-桃園大興西餐廳 / [25.01052, 121.2969] / arr: 2024-11-25 06:01:46+00:00 dep: 2024-11-25 06:06:46+00:00
# 	stop_time_arrival_from_trip_start: 5:25:49
# 	stop_time_departure_from_trip_start: 5:30:49
# 	~ movement time: 0:08:11 ~
# 17 --> c000092 / 肯德基-桃園中山餐廳 / [24.99077, 121.2904] / arr: 2024-11-25 06:14:57+00:00 dep: 2024-11-25 06:19:57+00:00
# 	stop_time_arrival_from_trip_start: 5:42:22
# 	stop_time_departure_from_trip_start: 5:47:22
# 	~ movement time: 0:11:33 ~
# 18 --> c000072 / 肯德基-桃園八德餐廳 / [24.95411, 121.29861] / arr: 2024-11-25 06:31:30+00:00 dep: 2024-11-25 06:36:30+00:00
# 	stop_time_arrival_from_trip_start: 6:01:56
# 	stop_time_departure_from_trip_start: 6:11:56
# 	~ movement time: 0:14:34 ~
# 19 --> c000147 / 肯德基-桃園中山餐廳 / [24.97461, 121.26382] / arr: 2024-11-25 06:51:04+00:00 dep: 2024-11-25 07:01:04+00:00
# 	stop_time_arrival_from_trip_start: 6:16:18
# 	stop_time_departure_from_trip_start: 6:21:18
# 	~ movement time: 0:04:22 ~
# 20 --> c000034 / 肯德基-中壢環中東餐廳 / [24.96236, 121.25531] / arr: 2024-11-25 07:05:26+00:00 dep: 2024-11-25 07:10:26+00:00
# 	stop_time_arrival_from_trip_start: 6:30:10
# 	stop_time_departure_from_trip_start: 6:40:10
# 	~ movement time: 0:08:52 ~
# 21 --> c000075 / 肯德基-中壢中和餐廳 / [24.95413, 121.22565] / arr: 2024-11-25 07:19:18+00:00 dep: 2024-11-25 07:29:18+00:00
# 	stop_time_arrival_from_trip_start: 6:41:40
# 	stop_time_departure_from_trip_start: 6:46:40
# 	~ movement time: 0:01:30 ~
# 22 --> c000048 / 肯德基-中壢中正餐廳 / [24.95537, 121.22162] / arr: 2024-11-25 07:30:48+00:00 dep: 2024-11-25 07:35:48+00:00
# 	stop_time_arrival_from_trip_start: 7:02:17
# 	stop_time_departure_from_trip_start: 7:12:17
# 	~ movement time: 0:15:37 ~
# 23 --> c000027 / 肯德基-楊梅中山餐廳 / [24.90889, 121.16696] / arr: 2024-11-25 07:51:25+00:00 dep: 2024-11-25 08:01:25+00:00
# 	stop_time_arrival_from_trip_start: 7:17:34
# 	stop_time_departure_from_trip_start: 7:22:34
# 	~ movement time: 0:05:17 ~
# 24 --> c000146 / 肯德基-楊梅大成餐廳 / [24.9104, 121.14567] / arr: 2024-11-25 08:06:42+00:00 dep: 2024-11-25 08:11:42+00:00
# 	stop_time_arrival_from_trip_start: 7:36:45
# 	stop_time_departure_from_trip_start: 7:41:45
# 	~ movement time: 0:14:11 ~
# 25 --> c000050 / 肯德基-中壢民族餐廳 / [24.95739, 121.20469] / arr: 2024-11-25 08:25:53+00:00 dep: 2024-11-25 08:30:53+00:00
# 	stop_time_arrival_from_trip_start: 7:56:24
# 	stop_time_departure_from_trip_start: 7:56:24
# 	~ movement time: 0:14:39 ~
# 26 --> arrival / None / [24.970504, 121.2516] / arr: 2024-11-25 08:45:32+00:00 dep: 2024-11-25 08:45:32+00:00
#
# calculating routes for tour: 1 / vehicle: mitsubishi_3 / stops: 12 / cost: 4926 / distance: 356596 / duration: 28599
# 	stop_time_arrival_from_trip_start: 0
# 	stop_time_departure_from_trip_start: 0
# 0 --> departure / None / [22.570109085287, 120.3416894676074] / arr: 2024-11-25 00:00:00+00:00 dep: 2024-11-25 00:00:00+00:00
# 	stop_time_arrival_from_trip_start: 1:36:20
# 	stop_time_departure_from_trip_start: 1:46:20
# 	~ movement time: 1:36:20 ~
# 1 --> c000009 / 肯德基-嘉義垂楊餐廳 / [23.47376, 120.44832] / arr: 2024-11-25 01:36:20+00:00 dep: 2024-11-25 01:46:20+00:00
# 	stop_time_arrival_from_trip_start: 1:52:36
# 	stop_time_departure_from_trip_start: 2:02:36
# 	~ movement time: 0:06:16 ~
# 2 --> c000065 / 肯德基-嘉義中興餐廳 / [23.4795, 120.42925] / arr: 2024-11-25 01:52:36+00:00 dep: 2024-11-25 02:02:36+00:00
# 	stop_time_arrival_from_trip_start: 3:13:25
# 	stop_time_departure_from_trip_start: 3:23:25
# 	~ movement time: 1:10:49 ~
# 3 --> c000037 / 肯德基-台中永福餐廳 / [24.18456, 120.62095] / arr: 2024-11-25 03:13:25+00:00 dep: 2024-11-25 03:23:25+00:00
# 	stop_time_arrival_from_trip_start: 3:26:16
# 	stop_time_departure_from_trip_start: 3:36:16
# 	~ movement time: 0:02:51 ~
# 4 --> c000157 / 肯德基-台中台糖餐廳 / [24.18367, 120.61457] / arr: 2024-11-25 03:26:16+00:00 dep: 2024-11-25 03:36:16+00:00
# 	stop_time_arrival_from_trip_start: 3:44:49
# 	stop_time_departure_from_trip_start: 3:54:49
# 	~ movement time: 0:08:33 ~
# 5 --> c000023 / 肯德基-台中三越餐廳 / [24.16563, 120.6438] / arr: 2024-11-25 03:44:49+00:00 dep: 2024-11-25 03:54:49+00:00
# 	stop_time_arrival_from_trip_start: 3:56:45
# 	stop_time_departure_from_trip_start: 4:01:45
# 	~ movement time: 0:01:56 ~
# 6 --> c000080 / 肯德基-中港愛買餐廳 / [24.16183, 120.65072] / arr: 2024-11-25 03:56:45+00:00 dep: 2024-11-25 04:01:45+00:00
# 	stop_time_arrival_from_trip_start: 4:09:33
# 	stop_time_departure_from_trip_start: 4:19:33
# 	~ movement time: 0:07:48 ~
# 7 --> c000119 / 肯德基-台中中港愛買餐廳 / [24.1748, 120.66333] / arr: 2024-11-25 04:09:33+00:00 dep: 2024-11-25 04:19:33+00:00
# 	stop_time_arrival_from_trip_start: 4:29:32
# 	stop_time_departure_from_trip_start: 4:39:32
# 	~ movement time: 0:09:59 ~
# 8 --> c000113 / 肯德基-北屯大買家餐廳 / [24.17624, 120.69952] / arr: 2024-11-25 04:29:32+00:00 dep: 2024-11-25 04:39:32+00:00
# 	stop_time_arrival_from_trip_start: 4:49:26
# 	stop_time_departure_from_trip_start: 5:54:26
# 	~ movement time: 0:09:54 ~
# 9 --> c000150 / 肯德基-台中潭子餐廳 / [24.21387, 120.70055] / arr: 2024-11-25 04:49:26+00:00 dep: 2024-11-25 05:54:26+00:00
# 9 --> break / None / [24.21387, 120.70055] / arr: 2024-11-25 04:49:26+00:00 dep: 2024-11-25 05:54:26+00:00
# 	stop_time_arrival_from_trip_start: 6:07:39
# 	stop_time_departure_from_trip_start: 6:17:39
# 	~ movement time: 0:13:13 ~
# 10 --> c000103 / 肯德基-台中豐原餐廳 / [24.25304, 120.72189] / arr: 2024-11-25 06:07:39+00:00 dep: 2024-11-25 06:17:39+00:00
# 	stop_time_arrival_from_trip_start: 7:56:39
# 	stop_time_departure_from_trip_start: 7:56:39
# 	~ movement time: 1:39:00 ~
# 11 --> arrival / None / [24.970504, 121.2516] / arr: 2024-11-25 07:56:39+00:00 dep: 2024-11-25 07:56:39+00:00
#
# calculating routes for tour: 2 / vehicle: mitsubishi_5 / stops: 19 / cost: 4887 / distance: 349700 / duration: 28486
# 	stop_time_arrival_from_trip_start: 0
# 	stop_time_departure_from_trip_start: 0
# 0 --> departure / None / [22.570109085287, 120.3416894676074] / arr: 2024-11-25 00:00:00+00:00 dep: 2024-11-25 00:56:54+00:00
# 	stop_time_arrival_from_trip_start: 0:03:06
# 	stop_time_departure_from_trip_start: 0:13:06
# 	~ movement time: 0:03:06 ~
# 1 --> c000015 / 肯德基-高雄沿海餐廳 / [22.56732, 120.35157] / arr: 2024-11-25 01:00:00+00:00 dep: 2024-11-25 01:10:00+00:00
# 	stop_time_arrival_from_trip_start: 0:24:48
# 	stop_time_departure_from_trip_start: 0:34:48
# 	~ movement time: 0:11:42 ~
# 2 --> c000035 / 肯德基-高雄中華五餐廳 / [22.60521, 120.30503] / arr: 2024-11-25 01:21:42+00:00 dep: 2024-11-25 01:31:42+00:00
# 	stop_time_arrival_from_trip_start: 0:43:13
# 	stop_time_departure_from_trip_start: 0:48:13
# 	~ movement time: 0:08:25 ~
# 3 --> c000044 / 肯德基-高雄三多餐廳 / [22.6198, 120.32263] / arr: 2024-11-25 01:40:07+00:00 dep: 2024-11-25 01:45:07+00:00
# 	stop_time_arrival_from_trip_start: 0:56:19
# 	stop_time_departure_from_trip_start: 1:06:19
# 	~ movement time: 0:08:06 ~
# 4 --> c000019 / 肯德基-鳳山中山餐廳 / [22.62448, 120.35702] / arr: 2024-11-25 01:53:13+00:00 dep: 2024-11-25 02:03:13+00:00
# 	stop_time_arrival_from_trip_start: 1:17:26
# 	stop_time_departure_from_trip_start: 1:22:26
# 	~ movement time: 0:11:07 ~
# 5 --> c000058 / 肯德基-高雄大順二餐廳 / [22.64441, 120.32627] / arr: 2024-11-25 02:14:20+00:00 dep: 2024-11-25 02:19:20+00:00
# 	stop_time_arrival_from_trip_start: 1:28:25
# 	stop_time_departure_from_trip_start: 1:33:25
# 	~ movement time: 0:05:59 ~
# 6 --> c000006 / 肯德基-高雄十全餐廳 / [22.64501, 120.30923] / arr: 2024-11-25 02:25:19+00:00 dep: 2024-11-25 02:30:19+00:00
# 	stop_time_arrival_from_trip_start: 1:51:06
# 	stop_time_departure_from_trip_start: 1:56:06
# 	~ movement time: 0:17:41 ~
# 7 --> c000024 / 肯德基-高雄楠梓二餐廳 / [22.72697, 120.32673] / arr: 2024-11-25 02:48:00+00:00 dep: 2024-11-25 02:53:00+00:00
# 	stop_time_arrival_from_trip_start: 2:33:40
# 	stop_time_departure_from_trip_start: 2:38:40
# 	~ movement time: 0:37:34 ~
# 8 --> c000040 / 肯德基-台南永康餐廳 / [23.04153, 120.24255] / arr: 2024-11-25 03:30:34+00:00 dep: 2024-11-25 03:35:34+00:00
# 	stop_time_arrival_from_trip_start: 4:09:31
# 	stop_time_departure_from_trip_start: 4:19:31
# 	~ movement time: 1:30:51 ~
# 9 --> c000043 / 肯德基-彰化中山餐廳 / [24.06824, 120.54014] / arr: 2024-11-25 05:06:25+00:00 dep: 2024-11-25 05:16:25+00:00
# 	stop_time_arrival_from_trip_start: 4:24:26
# 	stop_time_departure_from_trip_start: 4:29:26
# 	~ movement time: 0:04:55 ~
# 10 --> c000140 / 肯德基-彰化民權餐廳 / [24.07694, 120.53719] / arr: 2024-11-25 05:21:20+00:00 dep: 2024-11-25 05:26:20+00:00
# 	stop_time_arrival_from_trip_start: 4:35:53
# 	stop_time_departure_from_trip_start: 4:40:53
# 	~ movement time: 0:06:27 ~
# 11 --> c000020 / 肯德基-彰化金馬餐廳 / [24.09398, 120.54057] / arr: 2024-11-25 05:32:47+00:00 dep: 2024-11-25 05:37:47+00:00
# 	stop_time_arrival_from_trip_start: 4:57:09
# 	stop_time_departure_from_trip_start: 5:07:09
# 	~ movement time: 0:16:16 ~
# 12 --> c000125 / 肯德基-台中烏日餐廳 / [24.10725, 120.63624] / arr: 2024-11-25 05:54:03+00:00 dep: 2024-11-25 06:04:03+00:00
# 	stop_time_arrival_from_trip_start: 5:12:25
# 	stop_time_departure_from_trip_start: 5:17:25
# 	~ movement time: 0:05:16 ~
# 13 --> c000036 / 肯德基-台中復興餐廳 / [24.11732, 120.658] / arr: 2024-11-25 06:09:19+00:00 dep: 2024-11-25 06:14:19+00:00
# 	stop_time_arrival_from_trip_start: 5:24:21
# 	stop_time_departure_from_trip_start: 5:29:21
# 	~ movement time: 0:06:56 ~
# 14 --> c000094 / 肯德基-台中五權西餐廳 / [24.14006, 120.65156] / arr: 2024-11-25 06:21:15+00:00 dep: 2024-11-25 06:26:15+00:00
# 	stop_time_arrival_from_trip_start: 5:35:27
# 	stop_time_departure_from_trip_start: 5:45:27
# 	~ movement time: 0:06:06 ~
# 15 --> c000063 / 肯德基-台中五權餐廳 / [24.15036, 120.67641] / arr: 2024-11-25 06:32:21+00:00 dep: 2024-11-25 06:42:21+00:00
# 	stop_time_arrival_from_trip_start: 5:54:24
# 	stop_time_departure_from_trip_start: 6:04:24
# 	~ movement time: 0:08:57 ~
# 16 --> c000081 / 肯德基-台中后庄餐廳 / [24.18977, 120.66255] / arr: 2024-11-25 06:51:18+00:00 dep: 2024-11-25 07:01:18+00:00
# 	stop_time_arrival_from_trip_start: 7:07:39
# 	stop_time_departure_from_trip_start: 7:12:39
# 	~ movement time: 1:03:15 ~
# 17 --> c000128 / 肯德基-新竹光復餐廳 / [24.78667, 121.01074] / arr: 2024-11-25 08:04:33+00:00 dep: 2024-11-25 08:09:33+00:00
# 	stop_time_arrival_from_trip_start: 7:54:46
# 	stop_time_departure_from_trip_start: 7:54:46
# 	~ movement time: 0:42:07 ~
# 18 --> arrival / None / [24.970504, 121.2516] / arr: 2024-11-25 08:51:40+00:00 dep: 2024-11-25 08:51:40+00:00
#
# calculating routes for tour: 3 / vehicle: mitsubishi_2 / stops: 18 / cost: 4916 / distance: 353646 / duration: 28697
# 	stop_time_arrival_from_trip_start: 0
# 	stop_time_departure_from_trip_start: 0
# 0 --> departure / None / [22.570109085287, 120.3416894676074] / arr: 2024-11-25 00:00:00+00:00 dep: 2024-11-25 00:53:47+00:00
# 	stop_time_arrival_from_trip_start: 0:06:13
# 	stop_time_departure_from_trip_start: 0:16:13
# 	~ movement time: 0:06:13 ~
# 1 --> c000085 / 肯德基-鳳山五甲一餐廳 / [22.59008, 120.32425] / arr: 2024-11-25 01:00:00+00:00 dep: 2024-11-25 01:10:00+00:00
# 	stop_time_arrival_from_trip_start: 0:20:07
# 	stop_time_departure_from_trip_start: 0:25:07
# 	~ movement time: 0:03:54 ~
# 2 --> c000064 / 肯德基-鳳山五甲二餐廳 / [22.60091, 120.33976] / arr: 2024-11-25 01:13:54+00:00 dep: 2024-11-25 01:18:54+00:00
# 	stop_time_arrival_from_trip_start: 0:36:42
# 	stop_time_departure_from_trip_start: 0:46:42
# 	~ movement time: 0:11:35 ~
# 3 --> c000069 / 肯德基-高雄大順餐廳 / [22.63253, 120.32548] / arr: 2024-11-25 01:30:29+00:00 dep: 2024-11-25 01:40:29+00:00
# 	stop_time_arrival_from_trip_start: 0:49:37
# 	stop_time_departure_from_trip_start: 0:59:37
# 	~ movement time: 0:02:55 ~
# 4 --> c000149 / 肯德基-高雄文化餐廳 / [22.62796, 120.31531] / arr: 2024-11-25 01:43:24+00:00 dep: 2024-11-25 01:53:24+00:00
# 	stop_time_arrival_from_trip_start: 1:06:04
# 	stop_time_departure_from_trip_start: 1:16:04
# 	~ movement time: 0:06:27 ~
# 5 --> c000041 / 肯德基-高雄站前餐廳 / [22.6379, 120.30108] / arr: 2024-11-25 01:59:51+00:00 dep: 2024-11-25 02:09:51+00:00
# 	stop_time_arrival_from_trip_start: 1:25:22
# 	stop_time_departure_from_trip_start: 1:30:22
# 	~ movement time: 0:09:18 ~
# 6 --> c000070 / 肯德基-高雄自由餐廳 / [22.66062, 120.30884] / arr: 2024-11-25 02:19:09+00:00 dep: 2024-11-25 02:24:09+00:00
# 	stop_time_arrival_from_trip_start: 1:41:32
# 	stop_time_departure_from_trip_start: 1:46:32
# 	~ movement time: 0:11:10 ~
# 7 --> c000116 / 肯德基-左營環球餐廳 / [22.68762, 120.30674] / arr: 2024-11-25 02:35:19+00:00 dep: 2024-11-25 02:40:19+00:00
# 	stop_time_arrival_from_trip_start: 1:56:34
# 	stop_time_departure_from_trip_start: 2:06:34
# 	~ movement time: 0:10:02 ~
# 8 --> c000139 / 肯德基-高雄後昌餐廳 / [22.71883, 120.2918] / arr: 2024-11-25 02:50:21+00:00 dep: 2024-11-25 03:00:21+00:00
# 	stop_time_arrival_from_trip_start: 2:25:40
# 	stop_time_departure_from_trip_start: 2:30:40
# 	~ movement time: 0:19:06 ~
# 9 --> c000012 / 肯德基-高雄岡山餐廳 / [22.79388, 120.29578] / arr: 2024-11-25 03:19:27+00:00 dep: 2024-11-25 03:24:27+00:00
# 	stop_time_arrival_from_trip_start: 3:49:50
# 	stop_time_departure_from_trip_start: 3:59:50
# 	~ movement time: 1:19:10 ~
# 10 --> c000005 / 肯德基-嘉義忠孝餐廳 / [23.49499, 120.45175] / arr: 2024-11-25 04:43:37+00:00 dep: 2024-11-25 04:53:37+00:00
# 	stop_time_arrival_from_trip_start: 6:10:55
# 	stop_time_departure_from_trip_start: 6:20:55
# 	~ movement time: 2:11:05 ~
# 11 --> c000145 / 肯德基-新竹清大餐廳 / [24.79592, 120.99814] / arr: 2024-11-25 07:04:42+00:00 dep: 2024-11-25 07:14:42+00:00
# 	stop_time_arrival_from_trip_start: 6:24:34
# 	stop_time_departure_from_trip_start: 6:29:34
# 	~ movement time: 0:03:39 ~
# 12 --> c000026 / 肯德基-新竹亞太餐廳 / [24.80531, 120.9862] / arr: 2024-11-25 07:18:21+00:00 dep: 2024-11-25 07:23:21+00:00
# 	stop_time_arrival_from_trip_start: 6:35:03
# 	stop_time_departure_from_trip_start: 6:45:03
# 	~ movement time: 0:05:29 ~
# 13 --> c000031 / 肯德基-新竹民生餐廳 / [24.81355, 120.97438] / arr: 2024-11-25 07:28:50+00:00 dep: 2024-11-25 07:38:50+00:00
# 	stop_time_arrival_from_trip_start: 6:56:21
# 	stop_time_departure_from_trip_start: 7:01:21
# 	~ movement time: 0:11:18 ~
# 14 --> c000126 / 肯德基-竹北自強餐廳 / [24.81657, 121.02569] / arr: 2024-11-25 07:50:08+00:00 dep: 2024-11-25 07:55:08+00:00
# 	stop_time_arrival_from_trip_start: 7:03:57
# 	stop_time_departure_from_trip_start: 7:08:57
# 	~ movement time: 0:02:36 ~
# 15 --> c000158 / 肯德基-竹北自強餐廳 / [24.81074, 121.02149] / arr: 2024-11-25 07:57:44+00:00 dep: 2024-11-25 08:02:44+00:00
# 	stop_time_arrival_from_trip_start: 7:15:07
# 	stop_time_departure_from_trip_start: 7:20:07
# 	~ movement time: 0:06:10 ~
# 16 --> c000076 / 肯德基-新竹竹北餐廳 / [24.82645, 121.01085] / arr: 2024-11-25 08:08:54+00:00 dep: 2024-11-25 08:13:54+00:00
# 	stop_time_arrival_from_trip_start: 7:58:17
# 	stop_time_departure_from_trip_start: 7:58:17
# 	~ movement time: 0:38:10 ~
# 17 --> arrival / None / [24.970504, 121.2516] / arr: 2024-11-25 08:52:04+00:00 dep: 2024-11-25 08:52:04+00:00
#
# calculating routes for tour: 4 / vehicle: isuzu_3 / stops: 24 / cost: 3040 / distance: 124674 / duration: 28526
# 	stop_time_arrival_from_trip_start: 0
# 	stop_time_departure_from_trip_start: 0
# 0 --> departure / None / [25.0633628527129, 121.5517443657892] / arr: 2024-11-25 00:00:00+00:00 dep: 2024-11-25 00:53:47+00:00
# 	stop_time_arrival_from_trip_start: 0:08:22
# 	stop_time_departure_from_trip_start: 0:18:22
# 	~ movement time: 0:08:22 ~
# 1 --> c000055 / 肯德基-台北中山餐廳 / [25.05177, 121.5436] / arr: 2024-11-25 01:02:09+00:00 dep: 2024-11-25 01:12:09+00:00
# 	stop_time_arrival_from_trip_start: 0:25:37
# 	stop_time_departure_from_trip_start: 0:30:37
# 	~ movement time: 0:07:15 ~
# 2 --> c000138 / 肯德基-三重三和餐廳 / [25.0363, 121.55691] / arr: 2024-11-25 01:19:24+00:00 dep: 2024-11-25 01:24:24+00:00
# 	stop_time_arrival_from_trip_start: 0:37:37
# 	stop_time_departure_from_trip_start: 0:47:37
# 	~ movement time: 0:07:00 ~
# 3 --> c000109 / 肯德基-台北莊敬餐廳 / [25.02795, 121.56387] / arr: 2024-11-25 01:31:24+00:00 dep: 2024-11-25 01:41:24+00:00
# 	stop_time_arrival_from_trip_start: 0:55:57
# 	stop_time_departure_from_trip_start: 1:05:57
# 	~ movement time: 0:08:20 ~
# 4 --> c000077 / 肯德基-台北永春餐廳 / [25.041, 121.57313] / arr: 2024-11-25 01:49:44+00:00 dep: 2024-11-25 01:59:44+00:00
# 	stop_time_arrival_from_trip_start: 1:15:38
# 	stop_time_departure_from_trip_start: 1:25:38
# 	~ movement time: 0:09:41 ~
# 5 --> c000011 / 肯德基-台北中崙餐廳 / [25.04721, 121.54245] / arr: 2024-11-25 02:09:25+00:00 dep: 2024-11-25 02:19:25+00:00
# 	stop_time_arrival_from_trip_start: 1:32:38
# 	stop_time_departure_from_trip_start: 1:42:38
# 	~ movement time: 0:07:00 ~
# 6 --> c000097 / 肯德基-台北南京西餐廳 / [25.05267, 121.52003] / arr: 2024-11-25 02:26:25+00:00 dep: 2024-11-25 02:36:25+00:00
# 	stop_time_arrival_from_trip_start: 1:45:34
# 	stop_time_departure_from_trip_start: 1:55:34
# 	~ movement time: 0:02:56 ~
# 7 --> c000079 / 肯德基-台北承德餐廳 / [25.05076, 121.51689] / arr: 2024-11-25 02:39:21+00:00 dep: 2024-11-25 02:49:21+00:00
# 	stop_time_arrival_from_trip_start: 2:00:11
# 	stop_time_departure_from_trip_start: 2:05:11
# 	~ movement time: 0:04:37 ~
# 8 --> c000016 / 肯德基-台北三越餐廳 / [25.04663, 121.51537] / arr: 2024-11-25 02:53:58+00:00 dep: 2024-11-25 02:58:58+00:00
# 	stop_time_arrival_from_trip_start: 2:11:42
# 	stop_time_departure_from_trip_start: 2:16:42
# 	~ movement time: 0:06:31 ~
# 9 --> c000154 / 肯德基-台北峨嵋餐廳 / [25.04348, 121.50713] / arr: 2024-11-25 03:05:29+00:00 dep: 2024-11-25 03:10:29+00:00
# 	stop_time_arrival_from_trip_start: 2:23:01
# 	stop_time_departure_from_trip_start: 2:28:01
# 	~ movement time: 0:06:19 ~
# 10 --> c000124 / 肯德基-台北萬大餐廳 / [25.02543, 121.50039] / arr: 2024-11-25 03:16:48+00:00 dep: 2024-11-25 03:21:48+00:00
# 	stop_time_arrival_from_trip_start: 2:40:16
# 	stop_time_departure_from_trip_start: 2:45:16
# 	~ movement time: 0:12:15 ~
# 11 --> c000002 / 肯德基-台北台大餐廳 / [25.01707, 121.53325] / arr: 2024-11-25 03:34:03+00:00 dep: 2024-11-25 03:39:03+00:00
# 	stop_time_arrival_from_trip_start: 2:54:18
# 	stop_time_departure_from_trip_start: 2:59:18
# 	~ movement time: 0:09:02 ~
# 12 --> c000122 / 肯德基-文山興隆餐廳 / [25.00079, 121.55484] / arr: 2024-11-25 03:48:05+00:00 dep: 2024-11-25 03:53:05+00:00
# 	stop_time_arrival_from_trip_start: 3:05:36
# 	stop_time_departure_from_trip_start: 4:15:36
# 	~ movement time: 0:06:18 ~
# 13 --> c000151 / 肯德基-文山木柵餐廳 / [24.98858, 121.56681] / arr: 2024-11-25 03:59:23+00:00 dep: 2024-11-25 05:09:23+00:00
# 13 --> break / None / [24.98858, 121.56681] / arr: 2024-11-25 03:59:23+00:00 dep: 2024-11-25 05:09:23+00:00
# 	stop_time_arrival_from_trip_start: 4:39:02
# 	stop_time_departure_from_trip_start: 4:49:02
# 	~ movement time: 0:23:26 ~
# 14 --> c000133 / 肯德基-台北南港餐廳 / [25.05579, 121.61395] / arr: 2024-11-25 05:32:49+00:00 dep: 2024-11-25 05:42:49+00:00
# 	stop_time_arrival_from_trip_start: 5:18:08
# 	stop_time_departure_from_trip_start: 5:28:08
# 	~ movement time: 0:29:06 ~
# 15 --> c000155 / 肯德基-永和中山餐廳 / [25.0062, 121.50575] / arr: 2024-11-25 06:11:55+00:00 dep: 2024-11-25 06:21:55+00:00
# 	stop_time_arrival_from_trip_start: 5:29:55
# 	stop_time_departure_from_trip_start: 5:34:55
# 	~ movement time: 0:01:47 ~
# 16 --> c000010 / 肯德基-中和福祥餐廳 / [25.00264, 121.49895] / arr: 2024-11-25 06:23:42+00:00 dep: 2024-11-25 06:28:42+00:00
# 	stop_time_arrival_from_trip_start: 5:40:55
# 	stop_time_departure_from_trip_start: 5:45:55
# 	~ movement time: 0:06:00 ~
# 17 --> c000108 / 肯德基-中和環球餐廳 / [25.00609, 121.47514] / arr: 2024-11-25 06:34:42+00:00 dep: 2024-11-25 06:39:42+00:00
# 	stop_time_arrival_from_trip_start: 5:51:09
# 	stop_time_departure_from_trip_start: 5:56:09
# 	~ movement time: 0:05:14 ~
# 18 --> c000018 / 肯德基-板橋埔墘餐廳 / [25.01751, 121.47736] / arr: 2024-11-25 06:44:56+00:00 dep: 2024-11-25 06:49:56+00:00
# 	stop_time_arrival_from_trip_start: 6:05:54
# 	stop_time_departure_from_trip_start: 6:15:54
# 	~ movement time: 0:09:45 ~
# 19 --> c000025 / 肯德基-新莊中港餐廳 / [25.0447, 121.45266] / arr: 2024-11-25 06:59:41+00:00 dep: 2024-11-25 07:09:41+00:00
# 	stop_time_arrival_from_trip_start: 6:25:31
# 	stop_time_departure_from_trip_start: 6:30:31
# 	~ movement time: 0:09:37 ~
# 20 --> c000134 / 肯德基-新莊輔大餐廳 / [25.03231, 121.43346] / arr: 2024-11-25 07:19:18+00:00 dep: 2024-11-25 07:24:18+00:00
# 	stop_time_arrival_from_trip_start: 6:35:54
# 	stop_time_departure_from_trip_start: 6:40:54
# 	~ movement time: 0:05:23 ~
# 21 --> c000068 / 肯德基-新莊民安餐廳 / [25.02345, 121.42558] / arr: 2024-11-25 07:29:41+00:00 dep: 2024-11-25 07:34:41+00:00
# 	stop_time_arrival_from_trip_start: 7:22:40
# 	stop_time_departure_from_trip_start: 7:32:40
# 	~ movement time: 0:41:46 ~
# 22 --> c000135 / 肯德基-桃園大園餐廳 / [25.06246, 121.20148] / arr: 2024-11-25 08:16:27+00:00 dep: 2024-11-25 08:26:27+00:00
# 	stop_time_arrival_from_trip_start: 7:55:26
# 	stop_time_departure_from_trip_start: 7:55:26
# 	~ movement time: 0:22:46 ~
# 23 --> arrival / None / [24.970504, 121.2516] / arr: 2024-11-25 08:49:13+00:00 dep: 2024-11-25 08:49:13+00:00
#
# calculating routes for tour: 5 / vehicle: isuzu_2 / stops: 19 / cost: 3216 / distance: 169850 / duration: 28401
# 	stop_time_arrival_from_trip_start: 0
# 	stop_time_departure_from_trip_start: 0
# 0 --> departure / None / [25.0633628527129, 121.5517443657892] / arr: 2024-11-25 00:00:00+00:00 dep: 2024-11-25 00:48:37+00:00
# 	stop_time_arrival_from_trip_start: 0:19:31
# 	stop_time_departure_from_trip_start: 0:24:31
# 	~ movement time: 0:19:31 ~
# 1 --> c000086 / 肯德基-新店北新餐廳 / [24.97327, 121.54287] / arr: 2024-11-25 01:08:08+00:00 dep: 2024-11-25 01:13:08+00:00
# 	stop_time_arrival_from_trip_start: 0:59:50
# 	stop_time_departure_from_trip_start: 1:04:50
# 	~ movement time: 0:35:19 ~
# 2 --> c000090 / 肯德基-基隆忠二餐廳 / [25.12979, 121.74067] / arr: 2024-11-25 01:48:27+00:00 dep: 2024-11-25 01:53:27+00:00
# 	stop_time_arrival_from_trip_start: 1:09:47
# 	stop_time_departure_from_trip_start: 1:14:47
# 	~ movement time: 0:04:57 ~
# 3 --> c000046 / 肯德基-基隆仁一餐廳 / [25.12789, 121.75095] / arr: 2024-11-25 01:58:24+00:00 dep: 2024-11-25 02:03:24+00:00
# 	stop_time_arrival_from_trip_start: 1:39:15
# 	stop_time_departure_from_trip_start: 1:49:15
# 	~ movement time: 0:24:28 ~
# 4 --> c000141 / 肯德基-汐止大同餐廳 / [25.06729, 121.65759] / arr: 2024-11-25 02:27:52+00:00 dep: 2024-11-25 02:37:52+00:00
# 	stop_time_arrival_from_trip_start: 2:02:26
# 	stop_time_departure_from_trip_start: 2:12:26
# 	~ movement time: 0:13:11 ~
# 5 --> c000049 / 肯德基-台北東湖二餐廳 / [25.06821, 121.61631] / arr: 2024-11-25 02:51:03+00:00 dep: 2024-11-25 03:01:03+00:00
# 	stop_time_arrival_from_trip_start: 2:28:26
# 	stop_time_departure_from_trip_start: 2:33:26
# 	~ movement time: 0:16:00 ~
# 6 --> c000074 / 肯德基-台北內湖餐廳 / [25.08252, 121.56485] / arr: 2024-11-25 03:17:03+00:00 dep: 2024-11-25 03:22:03+00:00
# 	stop_time_arrival_from_trip_start: 2:46:10
# 	stop_time_departure_from_trip_start: 2:56:10
# 	~ movement time: 0:12:44 ~
# 7 --> c000039 / 肯德基-台北士林餐廳 / [25.0873, 121.5259] / arr: 2024-11-25 03:34:47+00:00 dep: 2024-11-25 03:44:47+00:00
# 	stop_time_arrival_from_trip_start: 2:59:54
# 	stop_time_departure_from_trip_start: 3:09:54
# 	~ movement time: 0:03:44 ~
# 8 --> c000127 / 肯德基-士林文昌餐廳 / [25.09447, 121.5223] / arr: 2024-11-25 03:48:31+00:00 dep: 2024-11-25 03:58:31+00:00
# 	stop_time_arrival_from_trip_start: 3:18:44
# 	stop_time_departure_from_trip_start: 3:23:44
# 	~ movement time: 0:08:50 ~
# 9 --> c000008 / 肯德基-台北石牌餐廳 / [25.11494, 121.51556] / arr: 2024-11-25 04:07:21+00:00 dep: 2024-11-25 04:12:21+00:00
# 	stop_time_arrival_from_trip_start: 3:28:46
# 	stop_time_departure_from_trip_start: 3:33:46
# 	~ movement time: 0:05:02 ~
# 10 --> c000148 / 肯德基-天母中山餐廳 / [25.11824, 121.53014] / arr: 2024-11-25 04:17:23+00:00 dep: 2024-11-25 04:22:23+00:00
# 	stop_time_arrival_from_trip_start: 3:33:56
# 	stop_time_departure_from_trip_start: 4:38:56
# 	~ movement time: 0:00:10 ~
# 11 --> c000098 / 肯德基-台北天母餐廳 / [25.11811, 121.53084] / arr: 2024-11-25 04:22:33+00:00 dep: 2024-11-25 05:27:33+00:00
# 11 --> break / None / [25.11811, 121.53084] / arr: 2024-11-25 04:22:33+00:00 dep: 2024-11-25 05:27:33+00:00
# 	stop_time_arrival_from_trip_start: 4:54:56
# 	stop_time_departure_from_trip_start: 5:04:56
# 	~ movement time: 0:16:00 ~
# 12 --> c000057 / 肯德基-北投光明餐廳 / [25.13673, 121.50431] / arr: 2024-11-25 05:43:33+00:00 dep: 2024-11-25 05:53:33+00:00
# 	stop_time_arrival_from_trip_start: 5:18:04
# 	stop_time_departure_from_trip_start: 5:23:04
# 	~ movement time: 0:13:08 ~
# 13 --> c000014 / 肯德基-淡水竹圍餐廳 / [25.14038, 121.45975] / arr: 2024-11-25 06:06:41+00:00 dep: 2024-11-25 06:11:41+00:00
# 	stop_time_arrival_from_trip_start: 5:30:06
# 	stop_time_departure_from_trip_start: 5:35:06
# 	~ movement time: 0:07:02 ~
# 14 --> c000132 / 肯德基-淡水中山二餐廳 / [25.16965, 121.44437] / arr: 2024-11-25 06:18:43+00:00 dep: 2024-11-25 06:23:43+00:00
# 	stop_time_arrival_from_trip_start: 5:39:53
# 	stop_time_departure_from_trip_start: 5:49:53
# 	~ movement time: 0:04:47 ~
# 15 --> c000101 / 肯德基-淡水中山餐廳 / [25.17742, 121.44318] / arr: 2024-11-25 06:28:30+00:00 dep: 2024-11-25 06:38:30+00:00
# 	stop_time_arrival_from_trip_start: 7:05:22
# 	stop_time_departure_from_trip_start: 7:15:22
# 	~ movement time: 1:15:29 ~
# 16 --> c000029 / 肯德基-龍潭北龍餐廳 / [24.86839, 121.21836] / arr: 2024-11-25 07:53:59+00:00 dep: 2024-11-25 08:03:59+00:00
# 	stop_time_arrival_from_trip_start: 7:18:35
# 	stop_time_departure_from_trip_start: 7:23:35
# 	~ movement time: 0:03:13 ~
# 17 --> c000160 / 肯德基-龍潭北龍餐廳 / [24.86458, 121.211] / arr: 2024-11-25 08:07:12+00:00 dep: 2024-11-25 08:12:12+00:00
# 	stop_time_arrival_from_trip_start: 7:53:21
# 	stop_time_departure_from_trip_start: 7:53:21
# 	~ movement time: 0:29:46 ~
# 18 --> arrival / None / [24.970504, 121.2516] / arr: 2024-11-25 08:41:58+00:00 dep: 2024-11-25 08:41:58+00:00
#
# calculating routes for tour: 6 / vehicle: isuzu_1 / stops: 15 / cost: 3349 / distance: 206159 / duration: 28029
# 	stop_time_arrival_from_trip_start: 0
# 	stop_time_departure_from_trip_start: 0
# 0 --> departure / None / [25.0633628527129, 121.5517443657892] / arr: 2024-11-25 00:00:00+00:00 dep: 2024-11-25 00:38:30+00:00
# 	stop_time_arrival_from_trip_start: 2:09:33
# 	stop_time_departure_from_trip_start: 2:14:33
# 	~ movement time: 2:09:33 ~
# 1 --> c000028 / 肯德基-宜蘭家樂福餐廳 / [24.75405, 121.74993] / arr: 2024-11-25 02:48:03+00:00 dep: 2024-11-25 02:53:03+00:00
# 	stop_time_arrival_from_trip_start: 2:16:18
# 	stop_time_departure_from_trip_start: 2:21:18
# 	~ movement time: 0:01:45 ~
# 2 --> c000152 / 肯德基-宜蘭舊城餐廳 / [24.75487, 121.75482] / arr: 2024-11-25 02:54:48+00:00 dep: 2024-11-25 02:59:48+00:00
# 	stop_time_arrival_from_trip_start: 2:23:11
# 	stop_time_departure_from_trip_start: 2:33:11
# 	~ movement time: 0:01:53 ~
# 3 --> c000033 / 肯德基-宜蘭新興餐廳 / [24.75614, 121.75809] / arr: 2024-11-25 03:01:41+00:00 dep: 2024-11-25 03:11:41+00:00
# 	stop_time_arrival_from_trip_start: 4:31:32
# 	stop_time_departure_from_trip_start: 4:36:32
# 	~ movement time: 1:58:21 ~
# 4 --> c000088 / 肯德基-新店光明餐廳 / [24.95911, 121.53831] / arr: 2024-11-25 05:10:02+00:00 dep: 2024-11-25 05:15:02+00:00
# 	stop_time_arrival_from_trip_start: 4:53:58
# 	stop_time_departure_from_trip_start: 4:58:58
# 	~ movement time: 0:17:26 ~
# 5 --> c000004 / 肯德基-中和興南餐廳 / [24.98914, 121.50996] / arr: 2024-11-25 05:32:28+00:00 dep: 2024-11-25 05:37:28+00:00
# 	stop_time_arrival_from_trip_start: 5:07:12
# 	stop_time_departure_from_trip_start: 5:12:12
# 	~ movement time: 0:08:14 ~
# 6 --> c000052 / 肯德基-中和連城餐廳 / [24.9962, 121.48799] / arr: 2024-11-25 05:45:42+00:00 dep: 2024-11-25 05:50:42+00:00
# 	stop_time_arrival_from_trip_start: 5:25:27
# 	stop_time_departure_from_trip_start: 5:35:27
# 	~ movement time: 0:13:15 ~
# 7 --> c000091 / 肯德基-板橋新埔餐廳 / [25.02277, 121.46726] / arr: 2024-11-25 06:03:57+00:00 dep: 2024-11-25 06:13:57+00:00
# 	stop_time_arrival_from_trip_start: 5:42:24
# 	stop_time_departure_from_trip_start: 5:52:24
# 	~ movement time: 0:06:57 ~
# 8 --> c000129 / 肯德基-板橋中山二餐廳 / [25.00961, 121.46117] / arr: 2024-11-25 06:20:54+00:00 dep: 2024-11-25 06:30:54+00:00
# 	stop_time_arrival_from_trip_start: 6:01:46
# 	stop_time_departure_from_trip_start: 6:11:46
# 	~ movement time: 0:09:22 ~
# 9 --> c000115 / 肯德基-土城金城餐廳 / [24.98584, 121.46398] / arr: 2024-11-25 06:40:16+00:00 dep: 2024-11-25 06:50:16+00:00
# 	stop_time_arrival_from_trip_start: 6:11:59
# 	stop_time_departure_from_trip_start: 6:21:59
# 	~ movement time: 0:00:13 ~
# 10 --> c000017 / 肯德基-台北土城餐廳 / [24.98616, 121.46479] / arr: 2024-11-25 06:50:29+00:00 dep: 2024-11-25 07:00:29+00:00
# 	stop_time_arrival_from_trip_start: 6:26:59
# 	stop_time_departure_from_trip_start: 6:36:59
# 	~ movement time: 0:05:00 ~
# 11 --> c000007 / 肯德基-土城裕民餐廳 / [24.98545, 121.45267] / arr: 2024-11-25 07:05:29+00:00 dep: 2024-11-25 07:15:29+00:00
# 	stop_time_arrival_from_trip_start: 6:48:01
# 	stop_time_departure_from_trip_start: 6:53:01
# 	~ movement time: 0:11:02 ~
# 12 --> c000100 / 肯德基-樹林中山餐廳 / [24.99192, 121.4237] / arr: 2024-11-25 07:26:31+00:00 dep: 2024-11-25 07:31:31+00:00
# 	stop_time_arrival_from_trip_start: 7:11:20
# 	stop_time_departure_from_trip_start: 7:16:20
# 	~ movement time: 0:18:19 ~
# 13 --> c000110 / 肯德基-三峽北大餐廳 / [24.94458, 121.37405] / arr: 2024-11-25 07:49:50+00:00 dep: 2024-11-25 07:54:50+00:00
# 	stop_time_arrival_from_trip_start: 7:47:09
# 	stop_time_departure_from_trip_start: 7:47:09
# 	~ movement time: 0:30:49 ~
# 14 --> arrival / None / [24.970504, 121.2516] / arr: 2024-11-25 08:25:39+00:00 dep: 2024-11-25 08:25:39+00:00
#
# calculating routes for tour: 7 / vehicle: isuzu_4 / stops: 11 / cost: 3846 / distance: 324583 / duration: 28722
# 	stop_time_arrival_from_trip_start: 0
# 	stop_time_departure_from_trip_start: 0
# 0 --> departure / None / [25.0633628527129, 121.5517443657892] / arr: 2024-11-25 00:00:00+00:00 dep: 2024-11-25 00:42:33+00:00
# 	stop_time_arrival_from_trip_start: 0:17:27
# 	stop_time_departure_from_trip_start: 0:22:27
# 	~ movement time: 0:17:27 ~
# 1 --> c000038 / 肯德基-永和中正餐廳 / [24.99907, 121.51711] / arr: 2024-11-25 01:00:00+00:00 dep: 2024-11-25 01:05:00+00:00
# 	stop_time_arrival_from_trip_start: 1:22:37
# 	stop_time_departure_from_trip_start: 1:27:37
# 	~ movement time: 1:00:10 ~
# 2 --> c000096 / 肯德基-新竹竹東餐廳 / [24.7428, 121.08422] / arr: 2024-11-25 02:05:10+00:00 dep: 2024-11-25 02:10:10+00:00
# 	stop_time_arrival_from_trip_start: 1:53:25
# 	stop_time_departure_from_trip_start: 1:58:25
# 	~ movement time: 0:25:48 ~
# 3 --> c000030 / 肯德基-苗栗頭份餐廳 / [24.69083, 120.91315] / arr: 2024-11-25 02:35:58+00:00 dep: 2024-11-25 02:40:58+00:00
# 	stop_time_arrival_from_trip_start: 2:23:09
# 	stop_time_departure_from_trip_start: 2:33:09
# 	~ movement time: 0:24:44 ~
# 4 --> c000089 / 肯德基-苗栗中正餐廳 / [24.55175, 120.81604] / arr: 2024-11-25 03:05:42+00:00 dep: 2024-11-25 03:15:42+00:00
# 	stop_time_arrival_from_trip_start: 3:18:15
# 	stop_time_departure_from_trip_start: 3:28:15
# 	~ movement time: 0:45:06 ~
# 5 --> c000061 / 肯德基-台中烏日餐廳 / [24.33462, 120.61525] / arr: 2024-11-25 04:00:48+00:00 dep: 2024-11-25 04:10:48+00:00
# 	stop_time_arrival_from_trip_start: 3:47:18
# 	stop_time_departure_from_trip_start: 4:52:18
# 	~ movement time: 0:19:03 ~
# 6 --> c000084 / 肯德基-台中沙鹿餐廳 / [24.23578, 120.55913] / arr: 2024-11-25 04:29:51+00:00 dep: 2024-11-25 05:34:51+00:00
# 6 --> break / None / [24.23578, 120.55913] / arr: 2024-11-25 04:29:51+00:00 dep: 2024-11-25 05:34:51+00:00
# 	stop_time_arrival_from_trip_start: 5:11:00
# 	stop_time_departure_from_trip_start: 5:21:00
# 	~ movement time: 0:18:42 ~
# 7 --> c000067 / 肯德基-台中大雅餐廳 / [24.2254, 120.64533] / arr: 2024-11-25 05:53:33+00:00 dep: 2024-11-25 06:03:33+00:00
# 	stop_time_arrival_from_trip_start: 5:34:58
# 	stop_time_departure_from_trip_start: 5:44:58
# 	~ movement time: 0:13:58 ~
# 8 --> c000093 / 肯德基-台中文心餐廳 / [24.17358, 120.67646] / arr: 2024-11-25 06:17:31+00:00 dep: 2024-11-25 06:27:31+00:00
# 	stop_time_arrival_from_trip_start: 7:08:55
# 	stop_time_departure_from_trip_start: 7:18:55
# 	~ movement time: 1:23:57 ~
# 9 --> c000159 / 肯德基-新竹新豐餐廳 / [24.8678, 120.99374] / arr: 2024-11-25 07:51:28+00:00 dep: 2024-11-25 08:01:28+00:00
# 	stop_time_arrival_from_trip_start: 7:58:42
# 	stop_time_departure_from_trip_start: 7:58:42
# 	~ movement time: 0:39:47 ~
# 10 --> arrival / None / [24.970504, 121.2516] / arr: 2024-11-25 08:41:15+00:00 dep: 2024-11-25 08:41:15+00:00
#
# calculating routes for tour: 8 / vehicle: mitsubishi_4 / stops: 12 / cost: 4930 / distance: 359055 / duration: 28392
# 	stop_time_arrival_from_trip_start: 0
# 	stop_time_departure_from_trip_start: 0
# 0 --> departure / None / [22.570109085287, 120.3416894676074] / arr: 2024-11-25 00:00:00+00:00 dep: 2024-11-25 00:10:46+00:00
# 	stop_time_arrival_from_trip_start: 0:49:14
# 	stop_time_departure_from_trip_start: 0:59:14
# 	~ movement time: 0:49:14 ~
# 1 --> c000047 / 肯德基-台南東門餐廳 / [22.98225, 120.22792] / arr: 2024-11-25 01:00:00+00:00 dep: 2024-11-25 01:10:00+00:00
# 	stop_time_arrival_from_trip_start: 1:02:51
# 	stop_time_departure_from_trip_start: 1:12:51
# 	~ movement time: 0:03:37 ~
# 2 --> c000099 / 肯德基-台南崇明餐廳 / [22.97638, 120.22119] / arr: 2024-11-25 01:13:37+00:00 dep: 2024-11-25 01:23:37+00:00
# 	stop_time_arrival_from_trip_start: 1:21:04
# 	stop_time_departure_from_trip_start: 1:26:04
# 	~ movement time: 0:08:13 ~
# 3 --> c000156 / 肯德基-台南金華餐廳 / [22.98102, 120.19147] / arr: 2024-11-25 01:31:50+00:00 dep: 2024-11-25 01:36:50+00:00
# 	stop_time_arrival_from_trip_start: 1:32:31
# 	stop_time_departure_from_trip_start: 1:37:31
# 	~ movement time: 0:06:27 ~
# 4 --> c000056 / 肯德基-台南安平餐廳 / [22.98849, 120.17317] / arr: 2024-11-25 01:43:17+00:00 dep: 2024-11-25 01:48:17+00:00
# 	stop_time_arrival_from_trip_start: 1:50:03
# 	stop_time_departure_from_trip_start: 1:55:03
# 	~ movement time: 0:12:32 ~
# 5 --> c000144 / 肯德基-台南海佃餐廳 / [23.0237, 120.19181] / arr: 2024-11-25 02:00:49+00:00 dep: 2024-11-25 02:05:49+00:00
# 	stop_time_arrival_from_trip_start: 1:56:54
# 	stop_time_departure_from_trip_start: 2:01:54
# 	~ movement time: 0:01:51 ~
# 6 --> c000142 / 肯德基-台南海佃餐廳 / [23.02865, 120.19058] / arr: 2024-11-25 02:07:40+00:00 dep: 2024-11-25 02:12:40+00:00
# 	stop_time_arrival_from_trip_start: 2:09:08
# 	stop_time_departure_from_trip_start: 2:19:08
# 	~ movement time: 0:07:14 ~
# 7 --> c000013 / 肯德基-台南西門二餐廳 / [23.00881, 120.20743] / arr: 2024-11-25 02:19:54+00:00 dep: 2024-11-25 02:29:54+00:00
# 	stop_time_arrival_from_trip_start: 2:27:09
# 	stop_time_departure_from_trip_start: 2:37:09
# 	~ movement time: 0:08:01 ~
# 8 --> c000123 / 肯德基-台南成大餐廳 / [22.99603, 120.22089] / arr: 2024-11-25 02:37:55+00:00 dep: 2024-11-25 02:47:55+00:00
# 	stop_time_arrival_from_trip_start: 3:20:35
# 	stop_time_departure_from_trip_start: 3:25:35
# 	~ movement time: 0:43:26 ~
# 9 --> c000120 / 肯德基-新營中正餐廳 / [23.3072, 120.31611] / arr: 2024-11-25 03:31:21+00:00 dep: 2024-11-25 03:36:21+00:00
# 	stop_time_arrival_from_trip_start: 4:12:48
# 	stop_time_departure_from_trip_start: 5:22:48
# 	~ movement time: 0:47:13 ~
# 10 --> c000095 / 肯德基-雲林虎尾餐廳 / [23.70955, 120.43659] / arr: 2024-11-25 04:23:34+00:00 dep: 2024-11-25 05:33:34+00:00
# 10 --> break / None / [23.70955, 120.43659] / arr: 2024-11-25 04:23:34+00:00 dep: 2024-11-25 05:33:34+00:00
# 	stop_time_arrival_from_trip_start: 7:53:12
# 	stop_time_departure_from_trip_start: 7:53:12
# 	~ movement time: 2:30:24 ~
# 11 --> arrival / None / [24.970504, 121.2516] / arr: 2024-11-25 08:03:58+00:00 dep: 2024-11-25 08:03:58+00:00
#
# calculating routes for tour: 9 / vehicle: mitsubishi_1 / stops: 9 / cost: 4986 / distance: 375109 / duration: 27785
# 	stop_time_arrival_from_trip_start: 0
# 	stop_time_departure_from_trip_start: 0
# 0 --> departure / None / [22.570109085287, 120.3416894676074] / arr: 2024-11-25 00:00:00+00:00 dep: 2024-11-25 00:00:00+00:00
# 	stop_time_arrival_from_trip_start: 1:06:41
# 	stop_time_departure_from_trip_start: 1:16:41
# 	~ movement time: 1:06:41 ~
# 1 --> c000121 / 肯德基-台南善化餐廳 / [23.12865, 120.2929] / arr: 2024-11-25 01:06:41+00:00 dep: 2024-11-25 01:16:41+00:00
# 	stop_time_arrival_from_trip_start: 2:46:56
# 	stop_time_departure_from_trip_start: 2:56:56
# 	~ movement time: 1:30:15 ~
# 2 --> c000003 / 肯德基-彰化員林餐廳 / [23.95943, 120.57111] / arr: 2024-11-25 02:46:56+00:00 dep: 2024-11-25 02:56:56+00:00
# 	stop_time_arrival_from_trip_start: 3:20:34
# 	stop_time_departure_from_trip_start: 3:30:34
# 	~ movement time: 0:23:38 ~
# 3 --> c000131 / 肯德基-南投南崗餐廳 / [23.91154, 120.67872] / arr: 2024-11-25 03:20:34+00:00 dep: 2024-11-25 03:30:34+00:00
# 	stop_time_arrival_from_trip_start: 3:43:17
# 	stop_time_departure_from_trip_start: 3:53:17
# 	~ movement time: 0:12:43 ~
# 4 --> c000071 / 肯德基-南投草屯餐廳 / [23.97505, 120.68364] / arr: 2024-11-25 03:43:17+00:00 dep: 2024-11-25 03:53:17+00:00
# 	stop_time_arrival_from_trip_start: 4:15:06
# 	stop_time_departure_from_trip_start: 4:20:06
# 	~ movement time: 0:21:49 ~
# 5 --> c000102 / 肯德基-大里國光餐廳 / [24.10062, 120.68234] / arr: 2024-11-25 04:15:06+00:00 dep: 2024-11-25 04:20:06+00:00
# 	stop_time_arrival_from_trip_start: 4:25:08
# 	stop_time_departure_from_trip_start: 5:35:08
# 	~ movement time: 0:05:02 ~
# 6 --> c000045 / 肯德基-大里中興餐廳 / [24.1104, 120.69003] / arr: 2024-11-25 04:25:08+00:00 dep: 2024-11-25 05:35:08+00:00
# 6 --> break / None / [24.1104, 120.69003] / arr: 2024-11-25 04:25:08+00:00 dep: 2024-11-25 05:35:08+00:00
# 	stop_time_arrival_from_trip_start: 5:46:52
# 	stop_time_departure_from_trip_start: 5:51:52
# 	~ movement time: 0:11:44 ~
# 7 --> c000022 / 肯德基-太平中山餐廳 / [24.14981, 120.71283] / arr: 2024-11-25 05:46:52+00:00 dep: 2024-11-25 05:51:52+00:00
# 	stop_time_arrival_from_trip_start: 7:43:05
# 	stop_time_departure_from_trip_start: 7:43:05
# 	~ movement time: 1:51:13 ~
# 8 --> arrival / None / [24.970504, 121.2516] / arr: 2024-11-25 07:43:05+00:00 dep: 2024-11-25 07:43:05+00:00

# %%
folium.LayerControl(collapsed=True, hideSingleBase=True).add_to(m)
m.fit_bounds(bounds)
m.save('here_tour_planning_v3_result_map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.9.3/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-3.7.1.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/bootstrap%405.2.2/dist/js/bootstrap.bundle.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.9.3/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/bootstrap%405.2.2/dist/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/%40fortawesome/fontawesome-free%406.2.0/css/all.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_b34c5c2592d240f086bece8dcdca7440%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.leaflet-container%20%7B%20font-size%3A%201rem%3B%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css%22/%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet-ant-path%401.1.2/dist/leaflet-ant-path.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium ...
